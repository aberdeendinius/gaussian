# %%
from rmgpy.molecule import *

# %%
m1 = Molecule(SMILES="CC1=CC=C2C(C=CC3=CC=CC=C32)=C1") #933
m1
# Out:
# Molecule(SMILES="CC1=CC=C2C(C=CC3=CC=CC=C32)=C1")

# %%
m2 = Molecule(SMILES="Cc1ccc2c(ccc3ccccc32)c1") #936
m2
# Out:
# Molecule(SMILES="CC1=CC=C2C(C=CC3=CC=CC=C32)=C1")

# %%
m3 = Molecule(SMILES="[CH2]C1=CC=C2C(C=CC3=CC=CC=C32)=C1") #937
m3
# Out:
# Molecule(SMILES="[CH2]C1=CC=C2C(C=CC3=CC=CC=C32)=C1")

# %%
Molecule(SMILES="[CH2]C1=CC=C2C(C=CC3C=CC=CC=32)=C1") #938
# Out:
# Molecule(SMILES="[CH2]C1=CC=C2C(C=CC3C=CC=CC=32)=C1")

# %%
m1.isIsomorphic(m2)
# Out:
# True
